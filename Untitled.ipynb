# %% [markdown]
# # install dependencies and setup

# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tensorflow
#   Using cached tensorflow-2.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (589.8 MB)
# Collecting tensorflow-gpu
#   Downloading tensorflow-gpu-2.12.0.tar.gz (2.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: matplotlib in /usr/lib/python3/dist-packages (3.5.1)
# Collecting numpy<2.0.0,>=1.23.5
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 12.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting keras>=3.0.0
#   Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.4 MB/s eta 0:00:00m eta 0:00:010:01
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (21.3)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorflow) (2.25.1)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.64.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 15.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Collecting absl-py>=1.0.0
#   Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 KB 11.0 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Collecting libclang>=13.0.0
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 11.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting h5py>=3.10.0
#   Downloading h5py-3.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 16.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 16.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 KB 15.3 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 KB 13.7 MB/s eta 0:00:00
# Collecting ml-dtypes~=0.3.1
#   Downloading ml_dtypes-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Collecting flatbuffers>=23.5.26
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 KB 20.5 MB/s eta 0:00:00
# Collecting tensorboard<2.17,>=2.16
#   Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 16.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.16.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 KB 13.6 MB/s eta 0:00:00
# Collecting python_version>"3.7"
#   Downloading python_version-0.0.2-py2.py3-none-any.whl (3.4 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Collecting namex
#   Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Collecting rich
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 KB 16.9 MB/s eta 0:00:00
# Collecting optree
#   Downloading optree-0.11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 KB 12.6 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.3/227.3 KB 11.4 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.6-py3-none-any.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 KB 23.4 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 15.2 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 KB 11.4 MB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.6 MB/s eta 0:00:0031m24.0 MB/s eta 0:00:01
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: tensorflow-gpu
#   Building wheel for tensorflow-gpu (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-ckq55r7l/tensorflow-gpu_4c9f8113bf9d4f37aff61d9d8203160c/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for tensorflow-gpu
#   Running setup.py clean for tensorflow-gpu
# Failed to build tensorflow-gpu
# Installing collected packages: python_version, namex, libclang, flatbuffers, wrapt, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-gpu, tensorboard-data-server, pygments, protobuf, numpy, mdurl, MarkupSafe, markdown, grpcio, google-pasta, gast, astunparse, absl-py, werkzeug, optree, opt-einsum, opencv-python, ml-dtypes, markdown-it-py, h5py, tensorboard, rich, keras, tensorflow
#   Running setup.py install for tensorflow-gpu ... error
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for tensorflow-gpu did not run successfully.
#   │ exit code: 1
#   ╰─> [18 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-ckq55r7l/tensorflow-gpu_4c9f8113bf9d4f37aff61d9d8203160c/setup.py", line 37, in <module>
#           raise Exception(TF_REMOVAL_WARNING)
#       Exception:
#
#       =========================================================
#       The "tensorflow-gpu" package has been removed!
#
#       Please install "tensorflow" instead.
#
#       Other than the name, the two packages have been identical
#       since TensorFlow 2.1, or roughly since Sep 2019. For more
#       information, see: pypi.org/project/tensorflow-gpu
#       =========================================================
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> tensorflow-gpu
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- ----------------
# absl-py                      2.1.0
# appdirs                      1.4.4
# apturl                       0.5.2
# argon2-cffi                  21.1.0
# astunparse                   1.6.3
# attrs                        21.2.0
# Babel                        2.8.0
# backcall                     0.2.0
# beautifulsoup4               4.10.0
# beniget                      0.4.1
# bleach                       4.1.0
# blinker                      1.4
# Brlapi                       0.8.3
# Brotli                       1.0.9
# certifi                      2020.6.20
# chardet                      4.0.0
# click                        8.0.3
# colorama                     0.4.4
# command-not-found            0.3
# cryptography                 3.4.8
# cupshelpers                  1.0
# cycler                       0.11.0
# dbus-python                  1.2.18
# decorator                    4.4.2
# defer                        1.0.6
# defusedxml                   0.7.1
# distro                       1.7.0
# distro-info                  1.1+ubuntu0.2
# dnspython                    2.5.0
# docker                       5.0.3
# docker-compose               1.29.2
# dockerpty                    0.4.1
# docopt                       0.6.2
# entrypoints                  0.4
# flatbuffers                  24.3.25
# fonttools                    4.29.1
# fs                           2.4.12
# gast                         0.5.4
# google-pasta                 0.2.0
# greenlet                     1.1.2
# grpcio                       1.64.0
# gyp                          0.1
# h5py                         3.11.0
# html5lib                     1.1
# httplib2                     0.20.2
# idna                         3.3
# importlib-metadata           4.6.4
# ipykernel                    6.7.0
# ipython                      7.31.1
# ipython_genutils             0.2.0
# ipywidgets                   6.0.0
# jedi                         0.18.0
# jeepney                      0.7.1
# Jinja2                       3.0.3
# jsonschema                   3.2.0
# jupyter-client               7.1.2
# jupyter-core                 4.9.1
# jupyterlab-pygments          0.1.2
# keras                        3.3.3
# keyring                      23.5.0
# kiwisolver                   1.3.2
# language-selector            0.1
# launchpadlib                 1.10.16
# lazr.restfulclient           0.14.4
# lazr.uri                     1.0.6
# libclang                     18.1.1
# louis                        3.20.0
# lxml                         4.8.0
# lz4                          3.1.3+dfsg
# macaroonbakery               1.3.1
# Markdown                     3.6
# markdown-it-py               3.0.0
# MarkupSafe                   2.1.5
# matplotlib                   3.5.1
# matplotlib-inline            0.1.3
# mdurl                        0.1.2
# ml-dtypes                    0.3.2
# more-itertools               8.10.0
# mpmath                       0.0.0
# msgpack                      1.0.3
# namex                        0.0.8
# nbclient                     0.5.6
# nbconvert                    6.4.0
# nbformat                     5.1.3
# nest-asyncio                 1.5.4
# netifaces                    0.11.0
# notebook                     6.4.8
# numpy                        1.26.4
# oauthlib                     3.2.0
# olefile                      0.46
# opt-einsum                   3.3.0
# optree                       0.11.0
# packaging                    21.3
# pandocfilters                1.5.0
# parso                        0.8.1
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       9.0.1
# pip                          24.0
# ply                          3.11
# prometheus-client            0.9.0
# prompt-toolkit               3.0.28
# protobuf                     4.25.3
# ptyprocess                   0.7.0
# py                           1.10.0
# pycairo                      1.20.1
# pycups                       2.0.1
# Pygments                     2.18.0
# PyGObject                    3.42.1
# PyJWT                        2.3.0
# pymacaroons                  0.13.0
# pymongo                      4.6.1
# PyNaCl                       1.5.0
# pynvim                       0.4.2
# pyparsing                    2.4.7
# pyRFC3339                    1.1
# pyrsistent                   0.18.1
# python-apt                   2.4.0+ubuntu3
# python-dateutil              2.8.1
# python-debian                0.1.43+ubuntu1.1
# python-dotenv                0.19.2
# python-version               0.0.2
# pythran                      0.10.0
# pytz                         2022.1
# pyxdg                        0.27
# PyYAML                       5.4.1
# pyzmq                        22.3.0
# reportlab                    3.6.8
# requests                     2.25.1
# rich                         13.7.1
# scipy                        1.8.0
# SecretStorage                3.3.1
# Send2Trash                   1.8.1b0
# setuptools                   59.6.0
# six                          1.16.0
# soupsieve                    2.3.1
# ssh-import-id                5.11
# sympy                        1.9
# systemd-python               234
# tensorboard                  2.16.2
# tensorboard-data-server      0.7.2
# tensorflow                   2.16.1
# tensorflow-io-gcs-filesystem 0.37.0
# termcolor                    2.4.0
# terminado                    0.13.1
# testpath                     0.5.0
# texttable                    1.6.4
# tornado                      6.1
# traitlets                    5.1.1
# typing_extensions            4.11.0
# ubuntu-drivers-common        0.0.0
# ubuntu-pro-client            8001
# ufoLib2                      0.13.1
# ufw                          0.36.1
# unattended-upgrades          0.1
# unicodedata2                 14.0.0
# urllib3                      1.26.5
# wadllib                      1.3.6
# wcwidth                      0.2.5
# webencodings                 0.5.1
# websocket-client             1.2.3
# Werkzeug                     3.0.3
# wheel                        0.37.1
# widgetsnbextension           2.0.0
# wrapt                        1.16.0
# xdg                          5
# xkit                         0.0.0
# zc.buildout                  2.13.2
# zipp                         1.0.0

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in /home/srestha/.local/lib/python3.10/site-packages (2.16.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/lib/python3/dist-packages (from tensorflow) (2.25.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from tensorflow) (59.6.0)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (1.64.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (3.3.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /home/srestha/.local/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/lib/python3/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: rich in /home/srestha/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in /home/srestha/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /home/srestha/.local/lib/python3.10/site-packages (from keras>=3.0.0->tensorflow) (0.11.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/srestha/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/srestha/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/srestha/.local/lib/python3.10/site-packages (from tensorboard<2.17,>=2.16->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/srestha/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/srestha/.local/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/srestha/.local/lib/python3.10/site-packages (from rich->keras>=3.0.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/srestha/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

# %%
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_62847/2091127585.py in <module>
# ----> 1 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'
